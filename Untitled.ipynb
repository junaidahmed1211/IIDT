# %%
import pandas as pd
import numpy as np
import os
from pandas import DataFrame

# %%
os.getcwd()
# Out:
# 'H:\\python'

# %%
stack=pd.read_csv("assignment//stackoverflow.csv")
stack
# Out:
#       RespondentID         Country         Salary  YearsCodedJob  OpenSource  \
# 0                3  United Kingdom  113750.000000             20           1
# 1               15  United Kingdom  100000.000000             20           0
# 2               18   United States  130000.000000             20           1
# 3               19   United States   82500.000000              3           0
# 4               26   United States  175000.000000             16           0
# 5               55         Germany   64516.129030              4           0
# 6               62           India    6636.323594              1           0
# 7               71   United States   65000.000000              1           0
# 8               73   United States  120000.000000             20           1
# 9               77   United States   96283.000000             20           1
# 10              82   United States  110000.000000             13           0
# ...

# %%
stack.shape
# Out:
# (6991, 23)

# %%
stack.isnull().sum()
# Out:
# RespondentID                               0
# Country                                    0
# Salary                                     0
# YearsCodedJob                              0
# OpenSource                                 0
# Hobby                                      0
# CompanySizeNumber                         31
# Remote                                     0
# CareerSatisfaction                         0
# Datascientist                              0
# Database administrator                     0
# Desktop applications developer             0
# Developer with stats/math background       0
# DevOps                                     0
# Embedded developer                         0
# Graphic designer                           0
# Graphics programming                       0
# Machine learning specialist                0
# Mobile developer                           0
# Quality assurance engineer                 0
# Systems administrator                      0
# ...

# %%
stack.groupby("Country",as_index=True).size()
# Out:
# Country
# Canada             619
# Germany            950
# India              666
# United Kingdom    1270
# United States     3486
# dtype: int64

# %%
stack['Country'].unique()
# Out:
# array(['United Kingdom', 'United States', 'Germany', 'India', 'Canada'], dtype=object)

# %%
stack.groupby("Country",as_index=False).agg({'Datascientist':np.sum})
# Out:
#           Country  Datascientist
# 0          Canada             43
# 1         Germany             75
# 2           India             43
# 3  United Kingdom             77
# 4   United States            266

# %%
stack.query('Country=="India"')['Datascientist'].sum()
# Out:
# 43

# %%
stack.query('Remote=="Remote"')['Remote'].count()
# Out:
# 718

# %%
(stack.groupby("Country").agg({'Salary':np.mean}))
# Out:
#                       Salary
# Country
# Canada          58226.407451
# Germany         52405.823429
# India           11557.674529
# United Kingdom  53962.871808
# United States   98313.127654

# %%
x=stack.query('Country=="India"')["Remote"]

# %%
round(163134.796)
# Out:
# 163135
