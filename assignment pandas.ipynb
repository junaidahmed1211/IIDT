# %%
import pandas as pd
from pandas import Series,DataFrame
names=pd.read_csv("H://python//assignment//names.csv")
names
# Out:
#       first_name   last_name                    company_name  \
# 0        Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1           Evan   Zigomalas              Cap Gemini America
# 2         France     Andrade             Elliott, John W Esq
# 3        Ulysses   Mcwalters                  Mcmahan, Ben L
# 4         Tyisha      Veness                  Champagne Room
# 5           Eric       Rampy         Thompson, Michael C Esq
# 6           Marg    Grasmick   Wrangle Hill Auto Auct & Slvg
# 7        Laquita       Hisaw           In Communications Inc
# 8           Lura    Manzella                 Bizerba Usa Inc
# 9         Yuette      Klapec                       Max Video
# 10      Fernanda      Writer            K & R Associates Inc
# 11   Charlesetta         Erm                Cain, John M Esq
# 12      Corrinne       Jaret               Sound Vision Corp
# 13        Niesha       Bruch          Rowley/hansell Petetin
# ...

# %%
names.loc[data['email'].str.endswith("gmail.com") & (data['first_name'] == 'Antonio')]
# Out:
#     first_name   last_name          company_name                address  \
# 272    Antonio  Villamarin      Combs Sheetmetal  353 Standish St #8264
# 427    Antonio      Heilig  Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# 272  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 427                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                         email  \
# 272  01388-777812  antonio.villamarin@gmail.com
# 427  01442-946357      antonio.heilig@gmail.com
#
#                                      web
# 272     http://www.combssheetmetal.co.uk
# 427  http://www.radissonsuitehotel.co.uk

# %%
x={'lat':[19,22,13,54,65],'long':[60,75,58,85,79]}
x
# Out:
# {'lat': [19, 22, 13, 54, 65], 'long': [60, 75, 58, 85, 79]}

# %%
names[['city']]
# Out:
#                                city
# 0                 St. Stephens Ward
# 1                        Abbey Ward
# 2    East Southbourne and Tuckton W
# 3                Hawerby cum Beesby
# 4        Greets Green and Lyng Ward
# 5                        Desborough
# 6                      Bargate Ward
# 7                      Chirton Ward
# 8                  Staple Hill Ward
# 9                           Parwich
# 10                       Wilmington
# 11             Loundsley Green Ward
# 12                         Dee Ward
# 13   Broxburn, Uphall and Winchburg
# 14                Weston-Super-Mare
# 15                        Carbrooke
# 16                       New Milton
# 17                          Parkham
# 18                     Darnall Ward
# 19                          Marldon
# 20              Prestatyn Community
# 21   Lye and Stourbridge North Ward
# 22                       Warlingham
# 23                          Newport
# 24                       Chichester
# ...

# %%
names = ['Buick', 'Cadillac', 'Chevrolet', 'Pontiac', 'Saturn', 'SAAB']
ds = [False, False,False, True, True, False]
pr = [20815, 40936, 16428, 18412, 13979, 29495]
print(names)
print(ds)
print(pr)
# Out:
# ['Buick', 'Cadillac', 'Chevrolet', 'Pontiac', 'Saturn', 'SAAB']
# [False, False, False, True, True, False]
# [20815, 40936, 16428, 18412, 13979, 29495]

# %%
my_dict = {'Make':names, 'Discontinued':ds, 'Price':pr }
cars = pd.DataFrame(my_dict)
print(cars)
# Out:
#    Discontinued       Make  Price
# 0         False      Buick  20815
# 1         False   Cadillac  40936
# 2         False  Chevrolet  16428
# 3          True    Pontiac  18412
# 4          True     Saturn  13979
# 5         False       SAAB  29495
